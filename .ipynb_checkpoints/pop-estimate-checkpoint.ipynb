# %% [markdown]
# # Deep Convolutional Methods for Population Estimation
# <hr>
#
# <p align="center">
#     <img src="Sample1.jpg" align="left" style="height: 200px;"/>
#     <img src="Sample2.jpg" align="left" style="height: 200px;"/>
#     <img src="Sample3.jpg" align="left" style="height: 200px;"/>
#     <img src="Sample4.jpg" align="left" style="height: 200px;"/>
#     <img src="Sample5.jpg" align="left" style="height: 200px;"/>
# </p>
#
#
# ### Objective
# This project estimates population statistics from satellite imagery of a region.
#
# Population estimation based on aerial or satellite photography is a highly practical and well-studied computational task. According to Robinson et. al. [<a href=#1>1</a>], "knowing where people live is a fundamental component of many decision making processes such as urban development, infectious disease containment, evacuation planning, risk management, conservation planning, and more." However, the recent advances of deep neural networks have received limited use in population estimation, with only a handful of relevant papers [<a href=#1>1</a>,<a href=#2>2</a>,<a href=#3>3</a>]. This project expands on that work by creating a novel dataset of U.S. Census tracts and developing a deep convolutional model for population estimation on these tracts. The model will predict the total population of a tract given its input image. Success will be measured by performance on an unseen test set of census tract images.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os

# %% [markdown]
# ## Data
#
# This project introduces a novel dataset of geographic information for population estimation by using U.S. Census Tracts. These ~70,000 tracts divide the land area of the United States into administrative regions for census record-keeping. Census tracts are subdivisions of counties and completely segement the U.S. landmass. They are the smallest geography for which American Community Survey data are tabulated for all types subject matter tables.
#
# There are two components to this data: <b>images</b> and <b>census records</b>.
#
# #### Images
#
# <img src="Sample2.jpg">
# <p style="text-align: center;"><i>Census Tract 7807, Kandiyohi County, Minnesota</i></p>
#
# Naively acquiring satellite imagery for every census tract would be a time-consuming task. Fortunately, a simple work-around exists. Images are scraped from the media feed of a Twitter bot (<a href="https://twitter.com/everytract">@everytract</a>) run by Neil Freeman. The bot tweets an image of a census tract every thirty minutes. It has currently tweeted ~36,000 of the ~70,000 total census tracts for the United States, providing a large and robust data set. Images are large and precisely delineated. A representative sample is shown above. Images were scraped using this <a href="https://github.com/furyutei/twMediaDownloader">application</a> to access the Twitter API. There are ~36,200 images in total used in this project.
#
# #### Census Records
#
# The census records used for this project where manually collected from the U.S. Census Bureau's online data portal (https://www.census.gov/data.html). The latest estimates from the 2018 American Community Survey were used for all (~37,000) census tracts corresponding to the available image data set. There are estimates for total population and total housing units for each census tract.

# %% [markdown]
# ### Preprocessing
#
# Census data for all tracts is aggregated into a single .csv file, ```Census_Combined.csv```.

# %%
'''
states = []
for filename in os.listdir("./Census Data"):
    print(filename)
    states.append(filename)
    
states.sort()
states.pop(0)

# Estimate!!Total housing units / DP05_0086E
# Estimate!!RACE!!Total population / DP05_0033E
# Geographic Area Name / NAME
# id / GEO_ID

alabama = pd.read_csv("./Census Data/Alabama 2018/ACSDP5Y2018.DP05_data_with_overlays_2020-11-10T102701.csv")
alabama = alabama[['GEO_ID','NAME','DP05_0033E','DP05_0086E']]
alabama.drop(index=0, inplace=True)

for state in states[1:]:
    temp = pd.read_csv("./Census Data/"+state+"/ACSDP5Y2018.csv")
    temp = temp[['GEO_ID','NAME','DP05_0033E','DP05_0086E']]
    temp.drop(index=0, inplace=True)
    alabama = alabama.append(temp, ignore_index=True)

combined = alabama
combined.to_csv('Census_Combined.csv')
'''
# Out:
# '\nstates = []\nfor filename in os.listdir("./Census Data"):\n    print(filename)\n    states.append(filename)\n    \nstates.sort()\nstates.pop(0)\n\n# Estimate!!Total housing units / DP05_0086E\n# Estimate!!RACE!!Total population / DP05_0033E\n# Geographic Area Name / NAME\n# id / GEO_ID\n\nalabama = pd.read_csv("./Census Data/Alabama 2018/ACSDP5Y2018.DP05_data_with_overlays_2020-11-10T102701.csv")\nalabama = alabama[[\'GEO_ID\',\'NAME\',\'DP05_0033E\',\'DP05_0086E\']]\nalabama.drop(index=0, inplace=True)\n\nfor state in states[1:]:\n    temp = pd.read_csv("./Census Data/"+state+"/ACSDP5Y2018.csv")\n    temp = temp[[\'GEO_ID\',\'NAME\',\'DP05_0033E\',\'DP05_0086E\']]\n    temp.drop(index=0, inplace=True)\n    alabama = alabama.append(temp, ignore_index=True)\n\ncombined = alabama\ncombined.to_csv(\'Census_Combined.csv\')\n'

# %%
# Last Tract: Census Tract 5603, Meeker County, Minnesota -> Row 36285

# %%
#Read Census data from Census_Combined.csv
census = pd.read_csv("Census_Combined.csv", nrows=36285)
census
# Out:
#        Unnamed: 0                GEO_ID  \
# 0               0  1400000US01001020100
# 1               1  1400000US01001020200
# 2               2  1400000US01001020300
# 3               3  1400000US01001020400
# 4               4  1400000US01001020500
# 5               5  1400000US01001020600
# 6               6  1400000US01001020700
# 7               7  1400000US01001020801
# 8               8  1400000US01001020802
# 9               9  1400000US01001020900
# 10             10  1400000US01001021000
# 11             11  1400000US01001021100
# 12             12  1400000US01003010100
# 13             13  1400000US01003010200
# 14             14  1400000US01003010300
# 15             15  1400000US01003010400
# 16             16  1400000US01003010500
# 17             17  1400000US01003010600
# 18             18  1400000US01003010701
# 19             19  1400000US01003010703
# 20             20  1400000US01003010704
# 21             21  1400000US01003010705
# 22             22  1400000US01003010800
# 23             23  1400000US01003010903
# 24             24  1400000US01003010904
# 25             25  1400000US01003010905
# 26             26  1400000US01003010906
# 27             27  1400000US01003011000
# 28             28  1400000US01003011101
# 29             29  1400000US01003011102
# ...           ...                   ...
# 36255       36255  1400000US27081201002
# 36256       36256  1400000US27083360100
# 36257       36257  1400000US27083360200
# 36258       36258  1400000US27083360300
# 36259       36259  1400000US27083360400
# 36260       36260  1400000US27083360500
# 36261       36261  1400000US27083360600
# 36262       36262  1400000US27083360700
# 36263       36263  1400000US27085950100
# 36264       36264  1400000US27085950200
# 36265       36265  1400000US27085950300
# 36266       36266  1400000US27085950400
# 36267       36267  1400000US27085950500
# 36268       36268  1400000US27085950600
# 36269       36269  1400000US27085950700
# 36270       36270  1400000US27087940100
# 36271       36271  1400000US27087940300
# 36272       36272  1400000US27089080100
# 36273       36273  1400000US27089080200
# 36274       36274  1400000US27089080300
# 36271    Census Tract 9403, Mahnomen County, Minnesota              2478
# 36272     Census Tract 801, Marshall County, Minnesota              2242
# 36273     Census Tract 802, Marshall County, Minnesota              2196
# 36274     Census Tract 803, Marshall County, Minnesota              2228
# 36275     Census Tract 804, Marshall County, Minnesota              2726
# 36276      Census Tract 7901, Martin County, Minnesota              2918
# 36277      Census Tract 7902, Martin County, Minnesota              2537
# 36278      Census Tract 7903, Martin County, Minnesota              2328
# 36279      Census Tract 7904, Martin County, Minnesota              1839
# 36280      Census Tract 7905, Martin County, Minnesota              5837
# 36281      Census Tract 7906, Martin County, Minnesota              4505
# 36282      Census Tract 5601, Meeker County, Minnesota              5083
# 36283      Census Tract 5602, Meeker County, Minnesota              4917
# 36284      Census Tract 5603, Meeker County, Minnesota              3686
#
#        TOTAL HOUSING UNITS  STANDARDIZED POPULATION
# 0                      779                      NaN
# 1                      852                      NaN
# 2                     1397                      NaN
# 3                     1867                      NaN
# 4                     4488                      NaN
# 5                     1413                      NaN
# 6                     1448                      NaN
# 7                     1224                      NaN
# 8                     4288                      NaN
# 9                     2472                      NaN
# 10                    1338                      NaN
# 11                    1749                      NaN
# 12                    2273                      NaN
# 13                    1277                      NaN
# 14                    3222                      NaN
# 15                    2110                      NaN
# 16                    1946                      NaN
# 17                    1421                      NaN
# 18                    3480                      NaN
# 19                    7049                      NaN
# 20                    2113                      NaN
# 21                    4532                      NaN
# 22                    3018                      NaN
# 23                    2080                      NaN
# 24                    2989                      NaN
# 25                    3743                      NaN
# 26                    1907                      NaN
# 27                    1899                      NaN
# 28                    4134                      NaN
# 29                    1880                      NaN
# ...                    ...                      ...
# 36255                 1459                      NaN
# 36256                 1672                      NaN
# 36257                 1360                      NaN
# 36258                 2168                      NaN
# 36259                 1935                      NaN
# 36260                 1720                      NaN
# 36261                 1356                      NaN
# 36262                 1040                      NaN
# 36263                 2338                      NaN
# 36264                 1666                      NaN
# 36265                 3004                      NaN
# 36266                 3364                      NaN
# 36267                 1336                      NaN
# 36268                 1895                      NaN
# 36269                 2222                      NaN
# 36270                 1320                      NaN
# 36271                 1471                      NaN
# 36272                 1340                      NaN
# 36273                 1144                      NaN
# 36274                 1064                      NaN
# 36275                 1267                      NaN
# 36276                 1416                      NaN
# 36277                 1211                      NaN
# 36278                 1131                      NaN
# 36279                  875                      NaN
# 36280                 3043                      NaN
# 36281                 2279                      NaN
# 36282                 2232                      NaN
# 36283                 2484                      NaN
# 36284                 1666                      NaN
#
# [36285 rows x 6 columns]

# %% [markdown]
# ### Exploratory Data Analysis:
#
# The accumulated census tracts showed a range of population values from 0 to ~40,000, with a mean population around 4,400. Manually inspecting imagery for very low population tracts confirmed that these population values were accurate and not in error. Because the entire land mass of the United States is divided into census tracts, this results in tracts for regions like airports, national parks, and remote islands with very low populations.

# %%
import statistics
print("Population Range: ",min(census["TOTAL POPULATION"])," - ",max(census["TOTAL POPULATION"]))
print("Mean Population: ", int(statistics.mean(census["TOTAL POPULATION"])))
# Out:
# Population Range:  0  -  39919
# Mean Population:  4446

# %% [markdown]
# All ~36,200 images were systematically renamed to their complete name and aggregated into one folder. Manual inspection of images shows a diverse range of shapes and sizes.

# %%
'''
for folder in os.listdir("./Images"):
    # Rename all images using csv
    try:
        temp_csv = pd.read_csv("./Images/"+folder+"/"+folder+".csv")
        #For row in temp_csv, match 
        temp_csv["Tweet content"] = temp_csv["Tweet content"].map(lambda a: a.split("https:",1)[0])
        temp_csv.to_csv("./Images/"+folder+"/"+folder+".csv")
    except:
        print(folder+" is not a valid folder.")
'''
# Out:
# '\nfor folder in os.listdir("./Images"):\n    # Rename all images using csv\n    try:\n        temp_csv = pd.read_csv("./Images/"+folder+"/"+folder+".csv")\n        #For row in temp_csv, match \n        temp_csv["Tweet content"] = temp_csv["Tweet content"].map(lambda a: a.split("https:",1)[0])\n        temp_csv.to_csv("./Images/"+folder+"/"+folder+".csv")\n    except:\n        print(folder+" is not a valid folder.")\n'

# %%
'''
for folder in os.listdir("./Images"):
    # Rename all images using csv
    try:
        temp_csv = pd.read_csv("./Images/"+folder+"/"+folder+".csv")
        #For row in temp_csv, match 
        for idx,row in temp_csv.iterrows():
            old_name = "./Images/" + folder+"/" + row['Saved filename']
            new_name = "./Images/" + row['Tweet content'][:-1] + '.jpg'
            os.rename(old_name,new_name)
    except:
        print(folder+" is not a valid folder.")
'''
# Out:
# '\nfor folder in os.listdir("./Images"):\n    # Rename all images using csv\n    try:\n        temp_csv = pd.read_csv("./Images/"+folder+"/"+folder+".csv")\n        #For row in temp_csv, match \n        for idx,row in temp_csv.iterrows():\n            old_name = "./Images/" + folder+"/" + row[\'Saved filename\']\n            new_name = "./Images/" + row[\'Tweet content\'][:-1] + \'.jpg\'\n            os.rename(old_name,new_name)\n    except:\n        print(folder+" is not a valid folder.")\n'

# %%
from PIL import Image

# Reshape all images to square dimensions
'''
for img_name in os.listdir("./Images"):
    try:
        img = Image.open("./Images/"+img_name)
        square_img = makeSquare(img,(255,255,255))
        square_img.save("./Images/"+img_name)
    except:
        print(img_name+" is not an image.")
'''        
def makeSquare(img, background_color):
    width, height = img.size
    if img.mode != 'RGB':
        img = img.convert('RGB')
    if width == height:
        return img
    elif width > height:
        result = Image.new(img.mode, (width, width), background_color)
        result.paste(img, (0, (width - height) // 2))
        return result
    else:
        result = Image.new(img.mode, (height, height), background_color)
        result.paste(img, ((height - width) // 2, 0))
        return result

# %%
'''
# Resize all images to 500x500
for img_name in os.listdir("./Images"):
    try:
        img = Image.open("./Images/"+img_name)
        img = img.resize((500,500))
        img.save("./Images/"+img_name)
    except:
        print(img_name+" is not an image.")
'''
# Out:
# '\n# Resize all images to 500x500\nfor img_name in os.listdir("./Images"):\n    try:\n        img = Image.open("./Images/"+img_name)\n        img = img.resize((500,500))\n        img.save("./Images/"+img_name)\n    except:\n        print(img_name+" is not an image.")\n'

# %% [markdown]
# ### Create Train / Val / Test Split
# 70 % Train | 10% Validation | 20% Test

# %%
from sklearn.model_selection import train_test_split

train_census, test_census = train_test_split(census, test_size = 0.2, random_state = 12)

# %%
### Standardize Population Data:

from sklearn.preprocessing import StandardScaler

train_pops = np.array(train_census["TOTAL POPULATION"])
train_pops = train_pops.reshape(-1,1)
scaler = StandardScaler()

scaler.fit(train_pops)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
train_census["STANDARDIZED POPULATION"] = scaler.transform(np.array(train_census["TOTAL POPULATION"]).reshape(-1,1))
test_census["STANDARDIZED POPULATION"] = scaler.transform(np.array(test_census["TOTAL POPULATION"]).reshape(-1,1))
# Out:
# /Users/nicholascarolan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/nicholascarolan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Create train, test directories
'''
for name in train_census["NAME"]:
    try:
        old_name = "./Images/" + name +".jpg"
        new_name = "./Images/train/train" + name + '.jpg'
        os.rename(old_name,new_name)
    except:
        print("train/"+name)

for name in test_census["NAME"]:
    try:
        old_name = "./Images/" + name +".jpg"
        new_name = "./Images/test/test" + name + '.jpg'
        os.rename(old_name,new_name)
    except:
        print("test/"+name)
'''
# Out:
# train/Census Tract 3.01, Champaign County, Illinois
# train/Census Tract 5644.01, Wayne County, Michigan
# train/Census Tract 101, Baltimore city, Maryland
# train/Census Tract 8416, Cook County, Illinois
# train/Census Tract 209, Hawaii County, Hawaii
# train/Census Tract 2664, Essex County, Massachusetts
# train/Census Tract 316.01, Riverside County, California
# train/Census Tract 8455.09, DuPage County, Illinois
# train/Census Tract 106, Androscoggin County, Maine
# train/Census Tract 5052.03, Carroll County, Maryland
# train/Census Tract 121, Rapides Parish, Louisiana
# train/Census Tract 1.34, Miami-Dade County, Florida
# train/Census Tract 3507, Marion County, Indiana
# train/Census Tract 512.01, Anoka County, Minnesota
# train/Census Tract 304.01, Allegan County, Michigan
# train/Census Tract 9798, Lawrence County, Alabama
# train/Census Tract 13.11, San Bernardino County, California
# train/Census Tract 244.03, Pinellas County, Florida
# train/Census Tract 12, Woodbury County, Iowa
# train/Census Tract 9532, Mohave County, Arizona
# train/Census Tract 201, Graves County, Kentucky
# train/Census Tract 2.01, Floyd County, Georgia
# train/Census Tract 5031.18, Santa Clara County, California
# train/Census Tract 12.02, Fulton County, Georgia
# train/Census Tract 1940, Oakland County, Michigan
# train/Census Tract 15, Calhoun County, Michigan
# train/Census Tract 9502, Harrison County, Kentucky
# train/Census Tract 201.03, San Diego County, California
# train/Census Tract 23, Calcasieu Parish, Louisiana
# train/Census Tract 1667, Oakland County, Michigan
# train/Census Tract 8610.13, Lake County, Illinois
# train/Census Tract 8281, Cook County, Illinois
# train/Census Tract 14.02, Lafayette Parish, Louisiana
# train/Census Tract 927.13, Maricopa County, Arizona
# train/Census Tract 114.03, Jefferson County, Kentucky
# train/Census Tract 5331.02, Tolland County, Connecticut
# train/Census Tract 303, Harvey County, Kansas
# train/Census Tract 119.06, Jefferson County, Kentucky
# train/Census Tract 69.01, El Paso County, Colorado
# train/Census Tract 9602, Howard County, Iowa
# train/Census Tract 41.03, Miami-Dade County, Florida
# train/Census Tract 41.02, Miami-Dade County, Florida
# train/Census Tract 51.02, Miami-Dade County, Florida
# train/Census Tract 502.19, Anoka County, Minnesota
# train/Census Tract 51.04, Miami-Dade County, Florida
# train/Census Tract 47.01, Miami-Dade County, Florida
# train/Census Tract 3018.01, Cook County, Illinois
# train/Census Tract 52.01, Miami-Dade County, Florida
# train/Census Tract 49.02, Miami-Dade County, Florida
# train/Census Tract 54.09, Miami-Dade County, Florida
# train/Census Tract 43.01, Miami-Dade County, Florida
# train/Census Tract 59.04, Miami-Dade County, Florida
# train/Census Tract 53.02, Miami-Dade County, Florida
# train/Census Tract 60.02, Miami-Dade County, Florida
# train/Census Tract 61.01, Miami-Dade County, Florida
# train/Census Tract 44.06, Miami-Dade County, Florida
# train/Census Tract 64.02, Miami-Dade County, Florida
# train/Census Tract 59.03, Miami-Dade County, Florida
# train/Census Tract 57.01, Miami-Dade County, Florida
# train/Census Tract 133.1, San Diego County, California
# train/Census Tract 45, Miami-Dade County, Florida
# train/Census Tract 47.03, Miami-Dade County, Florida
# train/Census Tract 44.05, Miami-Dade County, Florida
# train/Census Tract 50.02, Miami-Dade County, Florida
# test/Census Tract 66.02, Miami-Dade County, Florida
# test/Census Tract 62.06, Miami-Dade County, Florida
# test/Census Tract 111, District of Columbia, District of Columbia
# test/Census Tract 8421, Cook County, Illinois
# test/Census Tract 30.02, Tulare County, California
# test/Census Tract 5706.02, Los Angeles County, California
# test/Census Tract 42.04, Miami-Dade County, Florida
# test/Census Tract 41.05, Miami-Dade County, Florida
# test/Census Tract 40, Miami-Dade County, Florida
# test/Census Tract 64.01, Miami-Dade County, Florida
# test/Census Tract 8129, Cook County, Illinois
# test/Census Tract 61.02, Miami-Dade County, Florida
# test/Census Tract 58.01, Miami-Dade County, Florida
# test/Census Tract 54.10, Miami-Dade County, Florida
# test/Census Tract 34.00, Allen County, Indiana
# test/Census Tract 20.21, Weld County, Colorado
# test/Census Tract 147.06, New Castle County, Delaware
# test/Census Tract 58.02, Miami-Dade County, Florida
# test/Census Tract 62.01, Miami-Dade County, Florida
# test/Census Tract 39.22, Miami-Dade County, Florida
# test/Census Tract 46.07, Miami-Dade County, Florida
# test/Census Tract 161, San Diego County, California
# test/Census Tract 44.04, Miami-Dade County, Florida
# test/Census Tract 4946, Hartford County, Connecticut
# test/Census Tract 55.01, Miami-Dade County, Florida
# test/Census Tract 2771, Los Angeles County, California

# %% [markdown]
# ### Create tf Data Sets
#
# Images are divided using a 70 % Train | 10% Validation | 20% Test split, grouped into batches of 32, and processed in Tensorflow datasets for quick use by the model.

# %%
BATCH_SIZE = 32

# %%
pop_lookup = {}

for idx,row in train_census.iterrows():
    pop_lookup[row["NAME"]] = row["STANDARDIZED POPULATION"]

for idx,row in test_census.iterrows():
    pop_lookup[row["NAME"]] = row["STANDARDIZED POPULATION"]

# %%
train_names = sorted([img_name for img_name in os.listdir("./Images/train/train")])
test_names = sorted([img_name for img_name in os.listdir("./Images/test/test")])

# %%
train_labels = [pop_lookup[img_name[:-4]] for img_name in train_names]
test_labels = [pop_lookup[img_name[:-4]] for img_name in test_names]

# %%
# Directories of train and test sets -> update these based on your local configuration
TRAIN_DIR = '/Users/nicholascarolan/Desktop/population-estimation/Images/train'
TEST_DIR = '/Users/nicholascarolan/Desktop/population-estimation/Images/test'

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    directory=TRAIN_DIR, labels=train_labels, label_mode='int', class_names=None,
    color_mode='rgb', batch_size=BATCH_SIZE, image_size=(500, 500), shuffle=True, seed=12,
    validation_split=0.125, subset="training", interpolation='bilinear', follow_links=True
)
# Out:
# Found 28953 files belonging to 1 classes.
# Using 25334 files for training.

# %%
val_data = tf.keras.preprocessing.image_dataset_from_directory(
    directory=TRAIN_DIR, labels=train_labels, label_mode='int', class_names=None,
    color_mode='rgb', batch_size=BATCH_SIZE, image_size=(500, 500), shuffle=True, seed=12,
    validation_split=0.125, subset="validation", interpolation='bilinear', follow_links=True
)
# Out:
# Found 28953 files belonging to 1 classes.
# Using 3619 files for validation.

# %%
test_data = tf.keras.preprocessing.image_dataset_from_directory(
    directory=TEST_DIR, labels=test_labels, label_mode='int', class_names=None,
    color_mode='rgb', batch_size=BATCH_SIZE, image_size=(500, 500), shuffle=True, seed=None,
    validation_split=None, subset=None, interpolation='bilinear', follow_links=True
)
# Out:
# Found 7231 files belonging to 1 classes.

# %% [markdown]
# ### Visualize Tensorflow Datasets
#
# Visualizations for test and training sets below display the total information in one batch, with 32 images and their corresponding stardarized population counts.

# %%
from matplotlib import pyplot as plt

# Test data set visualization

for image, label in test_data.take(1):
    print("Image Batch Shape: ", image.numpy().shape)
    print("Labels: ", label.numpy())
    plt.figure(figsize=(15, 15))
    for i in range(BATCH_SIZE):
        ax = plt.subplot(4, 8, i + 1)
        plt.imshow(image[i].numpy().astype(np.uint8))
        plt.title(label[i].numpy())
        plt.axis("off")
# Out:
# Image Batch Shape:  (32, 500, 500, 3)
# Labels:  [-2.3198541e-01  5.6504273e-01 -5.0027895e-01  1.4881470e+00
#  -8.6716491e-01  4.0234383e-02 -1.0220336e+00  3.6432204e+00
#   1.6238429e-01 -1.3902283e+00  3.3077666e-01  1.9815676e-01
#   8.6736375e-01  3.5894113e-03  1.9274504e+00  1.5352620e+00
#  -1.0447185e+00 -7.8645873e-01 -2.8084537e-01  2.6926544e-01
#   3.0896416e-01  3.2772291e-01 -3.3014157e-01  8.4118879e-01
#   1.5849944e+00  4.0493912e-01 -5.3648770e-01 -1.0713297e+00
#  -7.3498124e-01 -2.0668292e-01  1.3655609e+00  8.9964622e-01]

# %%
# Training data set visualization

for image, label in train_data.take(1):
    print("Image Batch Shape: ", image.numpy().shape)
    print("Labels: ", label.numpy())
    plt.figure(figsize=(15, 15))
    for i in range(BATCH_SIZE):
        ax = plt.subplot(4, 8, i + 1)
        plt.imshow(image[i].numpy().astype(np.uint8))
        plt.title(label[i].numpy())
        plt.axis("off")
# Out:
# Image Batch Shape:  (32, 500, 500, 3)
# Labels:  [ 0.13577306 -1.0394835  -0.9260586   2.354975    0.06291936  0.31027293
#  -0.6381338   0.10130934 -0.11986924 -0.7912575   0.12661181  3.7391953
#  -0.58796513 -0.15520546 -1.1891172  -0.38598153 -0.1783267  -0.14299047
#  -0.6097776   0.7740063  -0.2398379  -0.44749275  1.2072022   2.1883278
#  -0.8257212  -0.21671666 -1.3470396  -0.6529663  -0.8872324   1.0418636
#  -0.67870504  0.52665275]

# %% [markdown]
# ## Model
#
# I intend on using a model similar to that deployed by Robinson et. al. in [<a href=#1>1</a>]. They use a modified version of the VGG-A convolutional neural network, a well-known network architecture for image recognition. Their model features five blocks, each with convolutional layer(s) followed by a maxpooling layer. Finally, there are two fully connected layers feeding into a softmax operation. They use the softmax operation on network output because they are performing a classification task. However, I am performing regression, and will just feed the last fully connected layer into a single numerical output.
#
# <img src="VGG-A.png">
#
# I intend on implementing a version of this model or a similar highly performant feature recognition model.

# %%
from tensorflow.keras import layers

img_height = 500
img_width = 500

# %%
model = tf.keras.models.Sequential([
    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    
    layers.Conv2D(128, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    
    layers.Conv2D(128, 3, padding='same', activation='relu'),
    layers.Conv2D(256, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    
    layers.Conv2D(512, 3, padding='same', activation='relu'),
    layers.Conv2D(512, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    
    layers.Conv2D(512, 3, padding='same', activation='relu'),
    layers.Conv2D(512, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(1)
])

# %%
model.compile(optimizer='adam',
              loss='mean_absolute_error',
              metrics=['mae','mse'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 500, 500, 3)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 500, 500, 64)      1792
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 250, 250, 64)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 250, 250, 128)     73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 125, 125, 128)     0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 125, 125, 128)     147584
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 125, 125, 256)     295168
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 62, 62, 256)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 62, 62, 512)       1180160
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 62, 62, 512)       2359808
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 31, 31, 512)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 31, 31, 512)       2359808
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 31, 31, 512)       2359808
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 15, 15, 512)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 115200)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               14745728
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 23,523,841
# Trainable params: 23,523,841
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training

# %% [markdown]
# ## Status
#
# ### Complete:
#
# I have manually downloaded census data for all relevant states and systemically aggregated the census data into one ```.csv``` file. I have downloaded all 37,000 images and systemically renamed each to the name of the tract it represents for easy queries. I have padded all images to square dimensions. I have resized all images to the same pixel dimensions.
#
# ### TODO:
#
# ~Stardardize population data, create training and test sets, build the model~, train it and evaluate its performance.

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ## Limitations / Improvements

# %% [markdown]
# ## References
#
# [<a id=1>1</a>] Robinson, C., Hohman, F., & Dilkina, B. (2017, November). <a href="https://deeppop.github.io/resources/robinson2017-deeppop.pdf">A deep learning approach for population estimation from satellite imagery.</a> In Proceedings of the 1st ACM SIGSPATIAL Workshop on Geospatial Humanities (pp. 47-54).
#
# [<a id=2>2</a>] Jacobs, N., Kraft, A., Rafique, M. U., & Sharma, R. D. (2018, November). <a href="https://arxiv.org/pdf/1810.09528.pdf">A weakly supervised approach for estimating spatial density functions from high-resolution satellite imagery.</a> In Proceedings of the 26th ACM SIGSPATIAL International Conference on Advances in Geographic Information Systems (pp. 33-42).
#
# [<a id=3>3</a>] Doupe, P., Bruzelius, E., Faghmous, J., & Ruchman, S. G. (2016, November). Equitable development through deep learning: The case of sub-national population density estimation. In Proceedings of the 7th Annual Symposium on Computing for Development (pp. 1-10).
